# %% [markdown]
# ## Import Library

# %%
import cv2
import numpy as np
import os
import time
import datetime
import mediapipe as mp
from matplotlib import pyplot as plt
import tensorflow as tf
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.callbacks import TensorBoard
from sklearn.metrics import multilabel_confusion_matrix, accuracy_score

# %% [markdown]
# ## Data Loading

# %%
# Path for exported data, numpy arrays
DATA_PATH = os.path.join('D:/College/PKMKC/Sound Degla/New Dataset') 

# Actions that we try to detect
actions = np.array(os.listdir(DATA_PATH))
# actions = np.array(['a', 'b', 'c', 'd', 'e', 'aku', 'anda', 'kamu', 'saya', 'selamat pagi', 'selamat siang'])
# actions = np.array(['aku', 'anda', 'kamu', 'saya', 'selamat pagi', 'selamat siang'])
# actions = np.array(['aku', 'apa', 'bagaimana', 'berapa', 'dimana', 'kamu', 'kapan', 'kenapa', 'nama', 'sama_sama', 'terimakasih', 'tidak'])

# Thirty videos worth of data
no_sequences = 100

# Videos are going to be 30 frames in length
sequence_length = 30

actions
# Out:
# array(['a', 'aku', 'anda', 'b', 'c', 'd', 'e', 'kamu', 'saya',
#        'selamat pagi', 'selamat siang'], dtype='<U13')

# %%
# Mengambil actions sebagai label dan mengubahnya menjadi numerical
label_map = {label:num for num, label in enumerate(actions)}
label_map
# Out:
# {'a': 0,
#  'aku': 1,
#  'anda': 2,
#  'b': 3,
#  'c': 4,
#  'd': 5,
#  'e': 6,
#  'kamu': 7,
#  'saya': 8,
#  'selamat pagi': 9,
#  'selamat siang': 10}

# %% [markdown]
# ## Data Preparation

# %%
# Mengambil keypoint landmark per frame setiap video untuk setiap action
sequences, labels = [], []      # Sequences -> fitur dari datanya

# Looping untuk setiap actions
for action in actions:
    # Looping untuk setiap video
    for sequence in range(no_sequences):
        window = []     # Window -> List untuk keypoint semua frame setiap video
        # Looping untuk setiap frame
        for frame_num in range(sequence_length):
            res = np.load(os.path.join(DATA_PATH, action, str(sequence), "{}.npy".format(frame_num)))
            # Memasukkan keypoint frame ke dalam list window
            window.append(res)
        # Memasukkan window ke list sequences per video
        sequences.append(window)
        # Menambah label untuk setiap action
        labels.append(label_map[action])

# %%
# Menjadikan sequences sebagai fitur dari data
X = np.array(sequences)

# Mengubah label menjadi categorical list
y = to_categorical(labels).astype(int)

# %%
# Memisahkan dataset menjadi data train & data test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.05)

# %% [markdown]
# ## Modeling

# %%
# Menyimpan log callback dari proses training
log_dir = os.path.join('Logs')
tb_callback = TensorBoard(log_dir=log_dir)

# %%
# Membuat arsitektur model
model = Sequential()
model.add(LSTM(32, return_sequences=True, activation='relu', input_shape=(30,1662)))    # input_shape = (frame, keypoint)
model.add(LSTM(128, return_sequences=True, activation='relu'))
model.add(LSTM(64, return_sequences=False, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(actions.shape[0], activation='softmax'))

# %%
# Melakukan compile pada model
optimizer = tf.keras.optimizers.Adam(learning_rate=0.0001)
model.compile(
    optimizer=optimizer, 
    loss='categorical_crossentropy', 
    metrics=['categorical_accuracy']
)

# %%
# Melakukan training
model.fit(
    X_train, 
    y_train, 
    epochs=300, 
    batch_size=12,
    callbacks=[tb_callback]
)
# Out:
# Epoch 1/300
# 88/88 [==============================] - 11s 53ms/step - loss: 2.3329 - categorical_accuracy: 0.1541
# Epoch 2/300
# 88/88 [==============================] - 5s 51ms/step - loss: 1.7217 - categorical_accuracy: 0.3244
# Epoch 3/300
# 88/88 [==============================] - 4s 50ms/step - loss: 1.2976 - categorical_accuracy: 0.4852
# Epoch 4/300
# 88/88 [==============================] - 5s 53ms/step - loss: 1.1543 - categorical_accuracy: 0.5579
# Epoch 5/300
# 88/88 [==============================] - 4s 49ms/step - loss: 0.9728 - categorical_accuracy: 0.6297
# Epoch 6/300
# 88/88 [==============================] - 4s 50ms/step - loss: 0.8923 - categorical_accuracy: 0.6450
# Epoch 7/300
# 88/88 [==============================] - 4s 48ms/step - loss: 1.0123 - categorical_accuracy: 0.6172
# Epoch 8/300
# 88/88 [==============================] - 5s 51ms/step - loss: 0.7988 - categorical_accuracy: 0.6823
# Epoch 9/300
# 88/88 [==============================] - 4s 48ms/step - loss: 0.8422 - categorical_accuracy: 0.6689
# Epoch 10/300
# 88/88 [==============================] - 4s 49ms/step - loss: 0.6685 - categorical_accuracy: 0.7368
# Epoch 11/300
# 88/88 [==============================] - 4s 50ms/step - loss: 0.6227 - categorical_accuracy: 0.7627
# Epoch 12/300
# 88/88 [==============================] - 5s 55ms/step - loss: 0.5766 - categorical_accuracy: 0.7684
# Epoch 13/300
# 88/88 [==============================] - 5s 55ms/step - loss: 0.5436 - categorical_accuracy: 0.7809
# Epoch 14/300
# 88/88 [==============================] - 5s 54ms/step - loss: 0.5935 - categorical_accuracy: 0.7522
# Epoch 15/300
# 88/88 [==============================] - 4s 51ms/step - loss: 0.5023 - categorical_accuracy: 0.8077
# Epoch 16/300
# 88/88 [==============================] - 4s 51ms/step - loss: 0.5577 - categorical_accuracy: 0.7837
# Epoch 17/300
# 88/88 [==============================] - 5s 52ms/step - loss: 0.6975 - categorical_accuracy: 0.7502
# Epoch 18/300
# 88/88 [==============================] - 4s 50ms/step - loss: 0.4030 - categorical_accuracy: 0.8440
# Epoch 19/300
# 88/88 [==============================] - 4s 51ms/step - loss: 0.5614 - categorical_accuracy: 0.7780
# Epoch 20/300
# 88/88 [==============================] - 4s 51ms/step - loss: 0.4870 - categorical_accuracy: 0.8077
# Epoch 21/300
# 88/88 [==============================] - 4s 51ms/step - loss: 0.3939 - categorical_accuracy: 0.8498
# Epoch 22/300
# 88/88 [==============================] - 5s 51ms/step - loss: 0.3064 - categorical_accuracy: 0.8766
# Epoch 23/300
# 88/88 [==============================] - 4s 50ms/step - loss: 0.3174 - categorical_accuracy: 0.8833
# Epoch 24/300
# 88/88 [==============================] - 5s 52ms/step - loss: 0.4978 - categorical_accuracy: 0.8038
# Epoch 25/300
# 88/88 [==============================] - 4s 51ms/step - loss: 0.3541 - categorical_accuracy: 0.8708
# Epoch 264/300
# 88/88 [==============================] - 5s 59ms/step - loss: 4.1831e-07 - categorical_accuracy: 1.0000
# Epoch 265/300
# 88/88 [==============================] - 5s 59ms/step - loss: 3.9972e-07 - categorical_accuracy: 1.0000
# Epoch 266/300
# 88/88 [==============================] - 5s 58ms/step - loss: 3.8078e-07 - categorical_accuracy: 1.0000
# Epoch 267/300
# 88/88 [==============================] - 5s 59ms/step - loss: 3.5580e-07 - categorical_accuracy: 1.0000
# Epoch 268/300
# 88/88 [==============================] - 5s 58ms/step - loss: 3.3435e-07 - categorical_accuracy: 1.0000
# Epoch 269/300
# 88/88 [==============================] - 5s 58ms/step - loss: 3.2933e-07 - categorical_accuracy: 1.0000
# Epoch 270/300
# 88/88 [==============================] - 5s 58ms/step - loss: 3.1040e-07 - categorical_accuracy: 1.0000
# Epoch 271/300
# 88/88 [==============================] - 5s 58ms/step - loss: 2.9055e-07 - categorical_accuracy: 1.0000
# Epoch 272/300
# 88/88 [==============================] - 5s 60ms/step - loss: 2.7481e-07 - categorical_accuracy: 1.0000
# Epoch 273/300
# 88/88 [==============================] - 5s 60ms/step - loss: 2.5781e-07 - categorical_accuracy: 1.0000
# Epoch 274/300
# 88/88 [==============================] - 6s 63ms/step - loss: 2.5097e-07 - categorical_accuracy: 1.0000
# Epoch 275/300
# 88/88 [==============================] - 5s 57ms/step - loss: 2.4001e-07 - categorical_accuracy: 1.0000
# Epoch 276/300
# 88/88 [==============================] - 5s 56ms/step - loss: 2.2690e-07 - categorical_accuracy: 1.0000
# Epoch 277/300
# 88/88 [==============================] - 5s 60ms/step - loss: 2.1492e-07 - categorical_accuracy: 1.0000
# Epoch 278/300
# 88/88 [==============================] - 5s 56ms/step - loss: 2.0625e-07 - categorical_accuracy: 1.0000
# Epoch 279/300
# 88/88 [==============================] - 5s 57ms/step - loss: 1.9142e-07 - categorical_accuracy: 1.0000
# Epoch 280/300
# 88/88 [==============================] - 5s 58ms/step - loss: 1.8959e-07 - categorical_accuracy: 1.0000
# Epoch 281/300
# 88/88 [==============================] - 5s 56ms/step - loss: 1.7351e-07 - categorical_accuracy: 1.0000
# Epoch 282/300
# 88/88 [==============================] - 5s 61ms/step - loss: 1.6712e-07 - categorical_accuracy: 1.0000
# Epoch 283/300
# 88/88 [==============================] - 6s 68ms/step - loss: 1.5754e-07 - categorical_accuracy: 1.0000
# Epoch 284/300
# 88/88 [==============================] - 5s 62ms/step - loss: 1.5309e-07 - categorical_accuracy: 1.0000
# Epoch 285/300
# 88/88 [==============================] - 5s 60ms/step - loss: 1.4066e-07 - categorical_accuracy: 1.0000
# Epoch 286/300
# 88/88 [==============================] - 5s 60ms/step - loss: 1.3427e-07 - categorical_accuracy: 1.0000
# Epoch 287/300
# 88/88 [==============================] - 6s 62ms/step - loss: 1.3119e-07 - categorical_accuracy: 1.0000
# Epoch 288/300
# 88/88 [==============================] - 5s 61ms/step - loss: 1.2115e-07 - categorical_accuracy: 1.0000
# Epoch 289/300
# 88/88 [==============================] - 5s 59ms/step - loss: 1.1693e-07 - categorical_accuracy: 1.0000
# Epoch 290/300
# 88/88 [==============================] - 5s 61ms/step - loss: 1.1054e-07 - categorical_accuracy: 1.0000
# Epoch 291/300
# 88/88 [==============================] - 5s 59ms/step - loss: 1.0484e-07 - categorical_accuracy: 1.0000
# Epoch 292/300
# 88/88 [==============================] - 5s 62ms/step - loss: 9.8561e-08 - categorical_accuracy: 1.0000
# Epoch 293/300
# 88/88 [==============================] - 5s 60ms/step - loss: 9.3542e-08 - categorical_accuracy: 1.0000
# Epoch 294/300
# 88/88 [==============================] - 5s 61ms/step - loss: 8.8295e-08 - categorical_accuracy: 1.0000
# Epoch 295/300
# 88/88 [==============================] - 5s 59ms/step - loss: 8.3618e-08 - categorical_accuracy: 1.0000
# Epoch 296/300
# 88/88 [==============================] - 6s 63ms/step - loss: 7.9169e-08 - categorical_accuracy: 1.0000
# Epoch 297/300
# 88/88 [==============================] - 5s 60ms/step - loss: 7.4720e-08 - categorical_accuracy: 1.0000
# Epoch 298/300
# 88/88 [==============================] - 5s 61ms/step - loss: 7.1069e-08 - categorical_accuracy: 1.0000
# Epoch 299/300
# 88/88 [==============================] - 5s 59ms/step - loss: 6.7647e-08 - categorical_accuracy: 1.0000
# Epoch 300/300
# 88/88 [==============================] - 5s 60ms/step - loss: 6.4909e-08 - categorical_accuracy: 1.0000

# %%
# Melakukan prediction dengan model yang telah dilatih
res = model.predict(X_test)

# Menampilkan data prediksi pada index ke-5
actions[np.argmax(res[4])]
# Out:
# 2/2 [==============================] - 1s 21ms/step
# 'c'

# %%
# Menampilkan data true pada index ke-5
actions[np.argmax(y_test[4])]
# Out:
# 'c'

# %% [markdown]
# ## Evaluation

# %%
# Melakukan prediction dengan model yang telah diload
yhat = model.predict(X_test)
# Out:
# 2/2 [==============================] - 0s 24ms/step

# %%
# Mengubah data asli dan hasil prediksi menjadi list
ytrue = np.argmax(y_test, axis=1).tolist()
yhat = np.argmax(yhat, axis=1).tolist()

# %%
# Menampilkan multilabel confusion matrix
multilabel_confusion_matrix(ytrue, yhat)
# Out:
# array([[[51,  0],
#         [ 0,  4]],
#
#        [[48,  0],
#         [ 0,  7]],
#
#        [[52,  0],
#         [ 0,  3]],
#
#        [[51,  0],
#         [ 0,  4]],
#
#        [[49,  0],
#         [ 0,  6]],
#
#        [[50,  0],
#         [ 0,  5]],
#
#        [[46,  0],
#         [ 0,  9]],
#
#        [[51,  0],
#         [ 0,  4]],
#
#        [[53,  0],
#         [ 0,  2]],
#
#        [[48,  0],
#         [ 0,  7]],
#
#        [[51,  0],
#         [ 0,  4]]], dtype=int64)

# %%
# Menampilkan akurasi dari model
acc = accuracy_score(ytrue, yhat)
acc = round(acc, 3)
print(f'Akurasi : {acc}')
# Out:
# Akurasi : 1.0

# %%
# Menyimpan model yang telah ditraining
now = datetime.datetime.now()
now = f'{now.year}-{now.month}-{now.day}'
model.save(f'Model/model-{acc} ({now}).h5')

# %% [markdown]
# ## Live Testing

# %%
# colors = [(245,117,16), (117,245,16), (16,117,245)]
# # Function untuk menampilkan visualisasi probabilitas dari label
# def prob_viz(res, actions, input_frame, colors):
#     output_frame = input_frame.copy()
#     for num, prob in enumerate(res):
#         cv2.rectangle(output_frame, (0,60+num*40), (int(prob*100), 90+num*40), colors[num], -1)
#         cv2.putText(output_frame, actions[num], (0, 85+num*40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2, cv2.LINE_AA)
        
#     return output_frame

# %%
# # 1. New detection variables
# sequence = []       # List untuk setiap frame
# sentence = []       # List untuk menaruh kata hasil prediksi
# predictions = []    # List untuk menaruh hasil prediksi
# threshold = 0.6     # Confidence matrix

# # Mengakses webcam
# cap = cv2.VideoCapture(0)
# # Set mediapipe model 
# with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
#     while cap.isOpened():

#         # Read feed
#         ret, frame = cap.read()

#         # Make detections
#         image, results = mediapipe_detection(frame, holistic)
#         # print(results)
        
#         # Draw landmarks
#         draw_styled_landmarks(image, results)
        
        
#         # 2. Prediction logic
#         # Mengekstrak keypoint
#         keypoints = extract_keypoints(results)
#         sequence.insert(0,keypoints)
#         sequence = sequence[:30]
#         # sequence.append(keypoints)
#         # sequence = sequence[-30:]
        
#         # Jika sudah 30 frame
#         if len(sequence) == 30:
#             # Melakukan prediction
#             res = model.predict(np.expand_dims(sequence, axis=0))[0]    # np.expand_dims -> Berfungsi untuk mengubah shape pada array
#             # Menampilkan hasil prediksi
#             print(actions[np.argmax(res)])
#             # Menambah hasil prediksi ke list predictions
#             predictions.append(np.argmax(res))
            
            
#         #3. Visualization logic
#             # Mengecek hasil dari prediksi apakah sama dengan hasil prediksi pada 10 frame terakhir atau tidak
#             if np.unique(predictions[-10:])[0]==np.argmax(res):
#                 # Mengecek apakah probabilitas hasil prediksi lebih dari threshold atau tidak
#                 if res[np.argmax(res)] > threshold: 
#                     # Jika dalam sentence sudah ada kata
#                     if len(sentence) > 0: 
#                         # Mengecek action yang sedang dideteksi tidak sama dengan action yang terakhir 
#                         if actions[np.argmax(res)] != sentence[-1]:
#                             # Menambahkan kata ke dalam sentence
#                             sentence.append(actions[np.argmax(res)])
#                     else:
#                         sentence.append(actions[np.argmax(res)])

#             # Jika dalam sentence sudah ada 5 kata
#             if len(sentence) > 5: 
#                 # Mengambil 5 kata yang terakhir dari sentence
#                 sentence = sentence[-5:]

#             # Viz probabilities
#             image = prob_viz(res, actions, image, colors)
        
#         # Mengambar box di window
#         cv2.rectangle(image, (0,0), (640, 40), (245, 117, 16), -1)
#         # Menaruh setence ke window
#         cv2.putText(image, ' '.join(sentence), (3,30), 
#                        cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
        
#         # Show to screen
#         cv2.imshow('OpenCV Feed', image)

#         # Break gracefully
#         if cv2.waitKey(10) & 0xFF == ord('q'):
#             break
#     cap.release()
#     cv2.destroyAllWindows()

# %%
cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[125], line 1
# ----> 1 cap.release()
#       2 cv2.destroyAllWindows()
#
# NameError: name 'cap' is not defined
